# %% [markdown]
# ![Logo](data:image/svg+xml;base64,...)

# %% [markdown]
# # <font color="red" >Observaciones:
# Los ejercicios ya estaban resueltos. Decidí organizar el notebook con las respuestas presentadas. </font>

# %% [markdown]
# # EJERCICIOS MARKDOWN (I)

# %% [markdown]
# Aquí tienes cinco sencillos ejercicios para practicar lo aprendido en la primera sesión de Markdown. Utiliza las celdas que hay debajo de cada enunciado y recuerda convertirlas a Markdown primero ;-)

# %% [markdown]
# ### Ejercicio 1: Cabeceras
# Crea las siguientes cabeceras:
#
# 1. Una cabecera de nivel 1 con el texto "Ciencia de Datos".
# 2. Una cabecera de nivel 2 con el texto "Introducción".
# 3. Una cabecera de nivel 3 con el texto "Herramientas".

# %% [markdown]
# ### <font color="red" >**Respuesta para el ejercicio 1:** </font>
# # Ciencia de Datos
# ## Introducción
# ### Herramientas de datos

# %% [markdown]
# ## Introducción

# %% [markdown]
# ### Herramientas

# %% [markdown]
# ### Ejercicio 2: Estilos de texto
# Escribe una frase que contenga las siguientes características:
#
# 1. La palabra "Markdown" en negritas.
# 2. La palabra "Jupyter" en cursivas.
# 3. La palabra "Python" en negritas y cursivas.

# %% [markdown]
# 1. La palabra **Markdown** debe estar en negritas.
# 2. La palabra *Jupyter* debe estar en cursivas.
# 3. La palabra ***Pyhton*** debe estar en ambos formatos.
#
# **Markdown** es un lenguaje utilizado habitualmente en los *Jupyter* notebooks, que suelen ser utilizados con otros lenguajes como ***Pyhton***.

# %% [markdown]
# ### Ejercicio 2: Estilos de texto
# Escribe una frase que contenga las siguientes características:
#
# 1. La palabra "Markdown" en negritas.
# 2. La palabra "Jupyter" en cursivas.
# 3. La palabra "Python" en negritas y cursivas.

# %% [markdown]
# ### <font color="red" >**Respuesta para el ejercicio 2:** </font>
# 1. Aquí escribimos la palabra **Markdown** (en negrita)
# 2. Aquí tenemos la palabra *Jupyter* (en cursiva)
# 3. Así se ve la palabra ***Python*** en negritas y cursiva

# %% [markdown]
# ### Ejercicio 3: Resaltados y HTML
# Crea una línea que contenga:
#
# 1. La palabra "resaltado" con un fondo amarillo usando Markdown.
# 2. La palabra "color" en azul usando HTML.
#
# Para este ejercicio tendrás que buscar un poco más en internet, venga que tú puedes.

# %% [markdown]
# ### <font color="red" >**Respuesta para el ejercicio 3:** </font>
#
# De hecho ya la tenía resuelta abajo:

# %% [markdown]
# <mark>resaltado</mark>

# %% [markdown]
# <font color="lightblue">color</font>

# %% [markdown]
# Otros ejemplos:

# %% [markdown]
# <mark> resaltado </mark>
#  <font color="blue"> color </font>

# %% [markdown]
# Como se producen los resultados:
# ```html
# <mark>resaltado</mark>
#  <font color="blue"> color </font>

# %% [markdown]
# ### Ejercicio 4: Citas
# Incluye la siguiente cita:
#
# > La Ciencia de Datos es el petróleo del siglo XXI.
#
# En uno y dos niveles de cita

# %% [markdown]
# ### <font color="red" >**Respuesta para el ejercicio 4:** </font>
#
# > `La Ciencia de Datos es el petróleo del siglo XXI.` A nivel 1
#
# >> `La Ciencia de Datos es el petróleo del siglo XXI.` A nivel 2
# >>> `La Ciencia de Datos es el petróleo del siglo XXI.` A nivel 3

# %% [markdown]
# Como se han producido:
# ```md
# > `La Ciencia de Datos es el petróleo del siglo XXI.` A nivel 1
#
# >> `La Ciencia de Datos es el petróleo del siglo XXI.` A nivel 2
# >>> `La Ciencia de Datos es el petróleo del siglo XXI.` A nivel 3

# %% [markdown]
# ### Ejercicio 5: Combinando todo
# Crea un texto que combine lo siguiente:
#
# 1. Una cabecera de nivel 2 con el texto "Curso de Markdown".
# 2. Una frase que contenga la palabra "importante" en negritas.
# 3. Una cita que diga: "Aprender es crecer".
# 4. La palabra "ejemplo" en cursivas y con un fondo verde usando HTML.
#
# Nota: Si no has sido capaz de encontrar como dar color de fondo usando HTML quizás <span style="background-color:yellow">*tienes que buscar más cerca de ti*</span>

# %% [markdown]
# ### <font color="red" >**Respuesta para el ejercicio 5:** </font>
# *Quizás <mark>profundizar</mark> en el contenido de este ejercio sea algo **importante***.
#
# > Aprender es crecer.
# >> `Crecer es vivir`
#
# Esto es un <font color="green" size="6" face="TimesNewRoman">*ejemplo*</font>.

# %% [markdown]
# ### <font color="red" >**EXTRA:** </font>
#
# * Como dar color de fundo usando HTML:
#
# ```html
#  <span style="background-color:yellow">*tienes que buscar más cerca de ti*</span>
#   <span style="background-color:green">*tienes que buscar más cerca de ti*</span>
#   <span style="background-color:red">*tienes que buscar más cerca de ti*</span>

# %% [markdown]
# Outputs:
#
#
#  <span style="background-color:yellow">*tienes que buscar más cerca de ti*</span>
#
#   <span style="background-color:green">*tienes que buscar más cerca de ti*</span>
#
#   <span style="background-color:red">*tienes que buscar más cerca de ti*</span>
