# %% [markdown]
# # 1. Mi primer notebook - BBK Bootcamp 2026

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# <h1> Header 1 <h1>
# <h1> Header 1 </h1>
# <h2> Header 2 <h2>
# <h3> Header 3 <h3>
# <h4> Header 4 <h4>
# <h5> Header 5 <h5>
# <h6> Header 6 <h6>
#
# >Recuerda
# >> LA

# %% [markdown]
# *Bold*
#
# **Italic**
#
# ***Bold Italic***
#
# ` Enhanced `

# %% [markdown]
# # Header
# ## Header
# ### Header

# %% [markdown]
# - # Header

# %% [markdown]
# 1. Primer
# 2. Segundo
# 3. Tercero
# 4.  Cuarto

# %% [markdown]
# * Elemento 1
# * Elemento 2
# * Elemento 3

# %% [markdown]
# - Uno
# - Dos
# - Tres

# %% [markdown]
# - [ ] Checkbox 1
# - [x] Checkbox 2

# %% [markdown]
# ```python
# string = "Hola mundo"

# %% [markdown]
# [Mi github (https://github.danillodbs16)](https://github.danillodbs16)
#
# [Mi github (https://github.danillodbs16)]

# %% [markdown]
# # Cargando una foto mía:
#
# 1. Como un link: [yo.jpg](yo.jpg)
# 2. Directamente:
# ![yo.jpg](yo.jpg)

# %% [markdown]
# # Controlando el tamaño de la imagen:

# %% [markdown]
# <img src="yo.jpg" width=400>

# %%
test = input("dime algo")
print("vale, ",str(test))
# Out:
# dime algo 2
# vale,  2
