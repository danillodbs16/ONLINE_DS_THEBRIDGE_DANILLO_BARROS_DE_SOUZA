# %% [markdown]
# # Mi primer notebook - BBK Bootcamp 2026

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# <h1> Header 1 <h1>
# <h1> Header 1 </h1>
# <h2> Header 2 <h2>
# <h3> Header 3 <h3>
# <h4> Header 4 <h4>
# <h5> Header 5 <h5>
# <h6> Header 6 <h6>
#
# >Recuerda
# >> LA

# %% [markdown]
# *Bold*
#
# **Italic**
#
# ***Bold Italic***

# %% [markdown]
# # Header
# ## Header
# ### Header

# %% [markdown]
# - # Header
