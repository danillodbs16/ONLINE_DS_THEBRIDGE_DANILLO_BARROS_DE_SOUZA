# %% [markdown]
# # Mi primer notebook - BBK Bootcamp 2026

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# <h1> Header 1 <h1>
# <h1> Header 1 </h1>
# <h2> Header 2 <h2>
# <h3> Header 3 <h3>
# <h4> Header 4 <h4>
# <h5> Header 5 <h5>
# <h6> Header 6 <h6>
#
# >Recuerda
# >> LA

# %% [markdown]
# *Bold*
#
# **Italic**
#
# ***Bold Italic***

# %% [markdown]
# # Header
# ## Header
# ### Header

# %% [markdown]
# - # Header

# %% [markdown]
# 1. Primer
# 2. Segundo
# 3. Tercero
# 4.  Cuarto

# %% [markdown]
# * Elemento 1
# * Elemento 2
# * Elemento 3

# %% [markdown]
# - Uno
# - Dos
# - Tres

# %% [markdown]
# - [ ] Checkbox 1
# - [x] Checkbox 2

# %% [markdown]
# ```python
# string = "Hola mundo"

# %% [markdown]
# [Mi github (https://github.danillodbs16)](https://github.danillodbs16)
